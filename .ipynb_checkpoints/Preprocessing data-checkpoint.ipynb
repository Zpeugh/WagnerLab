# %% [markdown]
# First, we will get the raw 2010 Haxby data.  Note that the 3 runs have been concatenated, and the beggining and ends of the runs have a minute of samples taken off.

# %%
import dataset_utilities
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore', category=DeprecationWarning)

raw_datasets = dataset_utilities.get_raw_2010_datasets()
# Out:
# /usr/lib/python2.7/dist-packages/sklearn/lda.py:4: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# /usr/lib/python2.7/dist-packages/sklearn/qda.py:4: DeprecationWarning: qda.QDA has been moved to discriminant_analysis.QuadraticDiscriminantAnalysis in 0.17 and will be removed in 0.19.
#   "in 0.17 and will be removed in 0.19.", DeprecationWarning)
# WARNING: Detected incorrect (nan) scl_ fields. Resetting to scl_slope=1.0 and scl_inter=0.0
#  * Please note: warnings are printed only once, but underlying problem might occur many times *
# /usr/local/lib/python2.7/dist-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# ...

# %% [markdown]
# Next we will plot the timeseries data for a single voxel for one subject.  Arbitrarily chosen.

# %%
subj_0 = raw_datasets["subject_0"]

plot = dataset_utilities.voxel_plot(subj_0, 8000)  #plotting the 8000th voxel.

# %% [markdown]
# Next, we will run the preprocessing steps.   These involve running the data through a GLM with a design matrix of the six motion parameters and the
